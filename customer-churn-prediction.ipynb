# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier,plot_tree
import matplotlib.pyplot as plt


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv

# %%
churn = pd.read_csv('/kaggle/input/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv')
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn = churn.drop(['customerID'],axis =1)
churn.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
churn = pd.get_dummies(churn,drop_first=True)
churn.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  gender_Male  Partner_Yes  \
# 0              0       1           29.85        False         True
# 1              0      34           56.95         True        False
# 2              0       2           53.85         True        False
# 3              0      45           42.30         True        False
# 4              0       2           70.70        False        False
#
#    Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 0           False             False                            True
# 1           False              True                           False
# 2           False              True                           False
# 3           False             False                            True
# 4           False              True                           False
#
#    MultipleLines_Yes  InternetService_Fiber optic  ...  TotalCharges_996.45  \
# ...

# %%
x=churn.iloc[:,:-1]
x
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  gender_Male  Partner_Yes  \
# 0                 0       1           29.85        False         True
# 1                 0      34           56.95         True        False
# 2                 0       2           53.85         True        False
# 3                 0      45           42.30         True        False
# 4                 0       2           70.70        False        False
# ...             ...     ...             ...          ...          ...
# 7038              0      24           84.80         True         True
# 7039              0      72          103.20        False         True
# 7040              0      11           29.60        False         True
# 7041              1       4           74.40         True         True
# 7042              0      66          105.65         True        False
#
#       Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# ...

# %%
y=churn.iloc[:,-1]
y
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041     True
# 7042    False
# Name: Churn_Yes, Length: 7043, dtype: bool

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.2, random_state = 20)

# %%
y_train
# Out:
# 805     False
# 1528    False
# 904     False
# 3396    False
# 861     False
#         ...
# 3915    False
# 1428     True
# 6537     True
# 4367    False
# 2522    False
# Name: Churn_Yes, Length: 1408, dtype: bool

# %%
rf_clf = RandomForestClassifier(random_state=20)

# %%
rf_clf = rf_clf.fit(x_train, y_train)

# %%
test_pred = rf_clf.predict(x_test)
test_pred
# Out:
# array([False, False, False, ..., False, False, False])

# %%
print(classification_report(test_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.81      0.87      4729
#         True       0.41      0.68      0.51       906
#
#     accuracy                           0.79      5635
#    macro avg       0.67      0.75      0.69      5635
# weighted avg       0.85      0.79      0.81      5635

# %%
dt_clf = DecisionTreeClassifier(random_state=20)

# %%
dt_clf = dt_clf.fit(x_train, y_train)

# %%
test_pred1 = dt_clf.predict(x_test)
test_pred1
# Out:
# array([False, False,  True, ..., False,  True, False])

# %%
print(classification_report(test_pred1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.85      0.83      0.84      4254
#         True       0.51      0.55      0.53      1381
#
#     accuracy                           0.76      5635
#    macro avg       0.68      0.69      0.68      5635
# weighted avg       0.77      0.76      0.76      5635
